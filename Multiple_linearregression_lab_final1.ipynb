# %%
print("TOWFEKA BENTA TOWHID")
print("ID: 11200120427")
# Out:
# TOWFEKA BENTA TOWHID
# ID: 11200120427

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Student_Performance1.csv')
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...                                ...                ...
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64
#
# [10000 rows x 5 columns]

# %%
x=df[['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced']]
y=df[['Performance Index']]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 4 columns]

# %%
y
# Out:
#       Performance Index
# 0                    91
# 1                    65
# 2                    45
# 3                    36
# 4                    66
# ...                 ...
# 9995                 23
# 9996                 58
# 9997                 74
# 9998                 95
# 9999                 64
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 44                8               77            6
# 5749              6               59            4
# 9722              2               43            8
# 5315              9               88            8
# 3916              6               56            4
# ...             ...              ...          ...
# 462               5               42            6
# 9878              2               75            7
# 878               2               66            5
# 7171              9               46            8
# 20                1               99            4
#
#       Sample Question Papers Practiced
# 44                                   4
# 5749                                 8
# 9722                                 6
# 5315                                 8
# 3916                                 8
# ...                                ...
# 462                                  2
# 9878                                 6
# 878                                  0
# 7171                                 3
# 20                                   3
#
# [7000 rows x 4 columns]

# %%
len(x_train)
# Out:
# 7000

# %%
len(x_test)
# Out:
# 3000

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.9885158450329676

# %%
reg.predict(x_test)
# Out:
# array([[26.36309342],
#        [78.83551769],
#        [56.07658989],
#        ...,
#        [41.20279741],
#        [49.1144539 ],
#        [39.6111836 ]])

# %%
y_test
# Out:
#       Performance Index
# 3756                 26
# 6834                 80
# 1106                 58
# 9602                 55
# 6601                 58
# ...                 ...
# 2064                 75
# 5672                 50
# 8476                 41
# 4757                 49
# 8699                 43
#
# [3000 rows x 1 columns]

# %% [markdown]
# ACCURACY

# %%
reg.score(x_test,y_test)
# Out:
# 0.9885158450329676

# %%
prediction_train= reg.predict(x_train)

# %%
y_pred = reg.predict(x_test)

# %%
x_train[ 'actual result'] = y_train

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 44                8               77            6
# 5749              6               59            4
# 9722              2               43            8
# 5315              9               88            8
# 3916              6               56            4
# ...             ...              ...          ...
# 462               5               42            6
# 9878              2               75            7
# 878               2               66            5
# 7171              9               46            8
# 20                1               99            4
#
#       Sample Question Papers Practiced  actual result  prediction result
# 44                                   4             71          71.148130
# 5749                                 8             45          46.939612
# 9722                                 6             21          20.731914
# 5315                                 8             90          86.944922
# 3916                                 8             44          43.882361
# ...                                ...            ...                ...
# 462                                  2             24          26.532178
# 9878                                 6             58          52.868294
# 878                                  0             43          41.567870
# 7171                                 3             39          43.160015
# 20                                   3             71          72.461811
#
# [7000 rows x 6 columns]

# %%
x_train['prediction result']=prediction_train

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 44                8               77            6
# 5749              6               59            4
# 9722              2               43            8
# 5315              9               88            8
# 3916              6               56            4
# ...             ...              ...          ...
# 462               5               42            6
# 9878              2               75            7
# 878               2               66            5
# 7171              9               46            8
# 20                1               99            4
#
#       Sample Question Papers Practiced  actual result  prediction result
# 44                                   4             71          71.148130
# 5749                                 8             45          46.939612
# 9722                                 6             21          20.731914
# 5315                                 8             90          86.944922
# 3916                                 8             44          43.882361
# ...                                ...            ...                ...
# 462                                  2             24          26.532178
# 9878                                 6             58          52.868294
# 878                                  0             43          41.567870
# 7171                                 3             39          43.160015
# 20                                   3             71          72.461811
#
# [7000 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title('actual vs predicted')
# Out:
# Text(0.5, 1.0, 'actual vs predicted')
