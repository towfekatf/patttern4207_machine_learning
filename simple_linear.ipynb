# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x = data['Glucose']
y = data['BloodPressure']

# %%
X = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
# Out:
# (0      148
#  1       85
#  2      183
#  3       89
#  4      137
#        ...
#  763    101
#  764    122
#  765    121
#  766    126
#  767     93
#  Name: Glucose, Length: 768, dtype: int64,
#  0      72
#  1      66
#  2      64
#  3      66
#  4      40
#         ..
#  763    76
#  764    70
#  765    72
#  766    60
#  767    70
#  Name: BloodPressure, Length: 768, dtype: int64)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt .xlabel("Glucose")
plt .ylabel("BloodPressure")
# Out:
# Text(0, 0.5, 'BloodPressure')

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.5,random_state=10)

# %%
x_train
# Out:
# 758    106
# 26     147
# 580    151
# 658    127
# 184    141
#       ...
# 369    133
# 320    129
# 527    116
# 125     88
# 265     96
# Name: Glucose, Length: 384, dtype: int64

# %%
import numpy as np
x_train = np.array(x_train).reshape(-1, 1)
x_train
# Out:
# array([[106],
#        [147],
#        [151],
#        [127],
#        [141],
#        [144],
#        [122],
#        [142],
#        [103],
#        [125],
#        [129],
#        [ 80],
#        [100],
#        [ 97],
#        [122],
#        [ 94],
#        [105],
#        [128],
#        [ 86],
#        [117],
#        [134],
#        [109],
#        [173],
#        [108],
#        [111],
#        [174],
#        [122],
#        [ 88],
#        [155],
#        [163],
#        [102],
#        [109],
#        [111],
#        [ 92],
#        [101],
#        [101],
#        [ 90],
#        [173],
#        [108],
#        [147],
#        [ 56],
#        [144],
#        [ 75],
#        [162],
#        [ 80],
#        [ 90],
#        [179],
#        [151],
#        [170],
#        [119],
#        [106],
#        [149],
#        [  0],
#        [180],
#        [ 87],
#        [119],
#        [106],
#        [ 88],
#        [119],
#        [164],
#        [ 76],
#        [102],
# ...

# %%
x_test = np.array(x_test).reshape(-1, 1)
x_test
# Out:
# array([[154],
#        [112],
#        [135],
#        [107],
#        [102],
#        [ 97],
#        [104],
#        [114],
#        [ 83],
#        [137],
#        [ 85],
#        [124],
#        [171],
#        [102],
#        [ 95],
#        [162],
#        [189],
#        [ 71],
#        [ 77],
#        [180],
#        [116],
#        [123],
#        [ 91],
#        [ 92],
#        [ 76],
#        [158],
#        [ 81],
#        [  0],
#        [141],
#        [187],
#        [130],
#        [ 73],
#        [111],
#        [ 90],
#        [135],
#        [125],
#        [118],
#        [111],
#        [165],
#        [ 91],
#        [125],
#        [139],
#        [115],
#        [112],
#        [129],
#        [ 67],
#        [125],
#        [125],
#        [134],
#        [120],
#        [108],
#        [176],
#        [128],
#        [135],
#        [128],
#        [ 91],
#        [ 91],
#        [114],
#        [110],
#        [ 99],
#        [111],
#        [ 89],
# ...

# %%
x_test
# Out:
# array([[154],
#        [112],
#        [135],
#        [107],
#        [102],
#        [ 97],
#        [104],
#        [114],
#        [ 83],
#        [137],
#        [ 85],
#        [124],
#        [171],
#        [102],
#        [ 95],
#        [162],
#        [189],
#        [ 71],
#        [ 77],
#        [180],
#        [116],
#        [123],
#        [ 91],
#        [ 92],
#        [ 76],
#        [158],
#        [ 81],
#        [  0],
#        [141],
#        [187],
#        [130],
#        [ 73],
#        [111],
#        [ 90],
#        [135],
#        [125],
#        [118],
#        [111],
#        [165],
#        [ 91],
#        [125],
#        [139],
#        [115],
#        [112],
#        [129],
#        [ 67],
#        [125],
#        [125],
#        [134],
#        [120],
#        [108],
#        [176],
#        [128],
#        [135],
#        [128],
#        [ 91],
#        [ 91],
#        [114],
#        [110],
#        [ 99],
#        [111],
#        [ 89],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 55.41195670320738

# %%
m = lr.coef_
m
# Out:
# array([0.11213199])

# %%
y_train1 = m*x_train + c
y_train1
# Out:
# array([[67.29794804],
#        [71.89535979],
#        [72.34388776],
#        [69.65271991],
#        [71.22256783],
#        [71.55896381],
#        [69.09205994],
#        [71.33469982],
#        [66.96155206],
#        [69.42845593],
#        [69.8769839 ],
#        [64.38251621],
#        [66.62515608],
#        [66.2887601 ],
#        [69.09205994],
#        [65.95236412],
#        [67.18581605],
#        [69.76485191],
#        [65.05530817],
#        [68.53139998],
#        [70.43764387],
#        [67.63434402],
#        [74.81079163],
#        [67.52221203],
#        [67.85860801],
#        [74.92292362],
#        [69.09205994],
#        [65.27957216],
#        [72.79241574],
#        [73.68947169],
#        [66.84942007],
#        [67.63434402],
#        [67.85860801],
#        [65.72810013],
#        [66.73728807],
#        [66.73728807],
#        [65.50383614],
#        [74.81079163],
#        [67.52221203],
#        [71.89535979],
#        [61.69134835],
# ...

# %%
y_train1
# Out:
# array([[67.29794804],
#        [71.89535979],
#        [72.34388776],
#        [69.65271991],
#        [71.22256783],
#        [71.55896381],
#        [69.09205994],
#        [71.33469982],
#        [66.96155206],
#        [69.42845593],
#        [69.8769839 ],
#        [64.38251621],
#        [66.62515608],
#        [66.2887601 ],
#        [69.09205994],
#        [65.95236412],
#        [67.18581605],
#        [69.76485191],
#        [65.05530817],
#        [68.53139998],
#        [70.43764387],
#        [67.63434402],
#        [74.81079163],
#        [67.52221203],
#        [67.85860801],
#        [74.92292362],
#        [69.09205994],
#        [65.27957216],
#        [72.79241574],
#        [73.68947169],
#        [66.84942007],
#        [67.63434402],
#        [67.85860801],
#        [65.72810013],
#        [66.73728807],
#        [66.73728807],
#        [65.50383614],
#        [74.81079163],
#        [67.52221203],
#        [71.89535979],
#        [61.69134835],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.scatter(x_train,y_train1,color = 'red')
plt .xlabel("Glucose")
plt .ylabel("BloodPressure")
# Out:
# Text(0, 0.5, 'BloodPressure')

# %%
y_test1 = lr.predict(x_test)
y_test1
# Out:
# array([72.68028375, 67.97074001, 70.54977586, 67.41008004, 66.84942007,
#        66.2887601 , 67.07368406, 68.19500399, 64.71891219, 70.77403985,
#        64.94317617, 69.31632393, 74.58652764, 66.84942007, 66.06449611,
#        73.5773397 , 76.60490353, 63.37332826, 64.04612022, 75.59571558,
#        68.41926798, 69.20419194, 65.61596814, 65.72810013, 63.93398823,
#        73.12881172, 64.4946482 , 55.4119567 , 71.22256783, 76.38063954,
#        69.98911589, 63.59759225, 67.85860801, 65.50383614, 70.54977586,
#        69.42845593, 68.64353197, 67.85860801, 73.91373568, 65.61596814,
#        69.42845593, 70.99830384, 68.30713599, 67.97074001, 69.8769839 ,
#        62.92480029, 69.42845593, 69.42845593, 70.43764387, 68.86779596,
#        67.52221203, 75.14718761, 69.76485191, 70.54977586, 69.76485191,
#        65.61596814, 65.61596814, 68.19500399, 67.74647602, 66.51302409,
#        67.85860801, 65.39170415, 67.18581605, 70.66190786, 65.72810013,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test)
plt.scatter(x_test,y_test1,color = 'red')
plt .xlabel("Glucose")
plt .ylabel("BloodPressure")
# Out:
# Text(0, 0.5, 'BloodPressure')
